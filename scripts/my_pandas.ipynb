# %%
print('Hallo world')

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/data_sport.csv').head(20)
df

# %%
df.info()

# %%
df = pd.DataFrame(
    {
        "Name": [
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss Elizabeth",
        ],
        "Age": [22, 35, 58],
        "Sex": ["male", "male", "female"],
    }
)

# %%
df

# %%
df['Age']

# %%
df

# %%
ages = pd.Series([22, 35, 58], name="Age")

# %%
ages

# %%
type(ages)

# %%
x = df["Age"].max()

# %%
x

# %%
print(x)

# %%
y = ages.max()

# %%
y

# %%
print(y)

# %%
df.describe()

# %%
ages.describe()

# %%
df.describe()
